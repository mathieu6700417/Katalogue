# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %%
from katalogue.insee.communes import DépôtINSEECommunes

dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC              NCC  \
# 6044      COM  17016  75.0  17  17D  171     1          ARCHIAC
# 20506     COM  52201  44.0  52  52D  523     0    FLAMMERECOURT
# 21432     COM  54308  44.0  54  54D  542     0         LEINTREY
# 31250     COM  74013  84.0  74  74D  744     1  ANTHY SUR LEMAN
# 32432     COM  77131  11.0  77  77D  771     0      COULOMMIERS
#
#                 NCCENR          LIBELLE   CAN  COMPARENT
# 6044           Archiac          Archiac  1707        NaN
# 20506    Flammerécourt    Flammerécourt  5209        NaN
# 21432         Leintrey         Leintrey  5401        NaN
# 31250  Anthy-sur-Léman  Anthy-sur-Léman  7415        NaN
# 32432      Coulommiers      Coulommiers  7705        NaN

# %%
from katalogue.datagouv.associations import DépôtDataGouvAssociations

# %%
dépôt = DépôtDataGouvAssociations()
assos = dépôt.associations(True)
assos.sample(5)
# Out:
# Lecture sauvegarde existante  /home/laurent/.katalogue/datagouv/locale_DépôtDataGouvAssociations_associations.pkl
#                      id                                              titre  \
# 1953767      W751255950                                      RALLYE PHENIX
# 227836   402P0402005553  DEPARTEMENTALE POUR LE TRANSPORT DES ELEVES DE...
# 286464   113S0113001496                                            SIDEROS
# 2069618      W353003131     ASSOCIATION DE PARENTS D'ELEVES DU CHAT CHEVRE
# 1708598      W883005871                                         FOUCH'ANIM
#
#                                                      objet  objet_social1  \
# 1953767  proposer aux enfants des membres des rencontre...         6000.0
# 227836   Etudier et poursuivre le transport des eleves ...            NaN
# 286464                                          En sommeil         6020.0
# 2069618  Diffuser la pensée laïque et défendre les inst...        15010.0
# 1708598  proposer, organiser différentes activités à de...        21020.0
#
#         objet_social2 date_creat adrs_codeinsee adrs_codepostal  \
# 1953767       11000.0 2020-02-24          75117         75017.0
# 227836            0.0        NaT          40192           40000
# 286464            0.0        NaT          11024           11100
# 2069618             0 1984-01-06        35001.0         35690.0
# 1708598           0.0 2021-10-29          88413         88100.0
#
#                                 titre_court date_disso  \
# 1953767                       RALLYE PHENIX        NaT
# 227836                                  NaN        NaT
# 286464                                  NaN        NaT
# 2069618  ASSOCIATION DE PARENTS D'ELEVES DU        NaT
# 1708598                          FOUCH'ANIM        NaT
#
#          objet_social_parent_id  \
# 1953767                  6000.0
# 227836                      NaN
# 286464                   6000.0
# 2069618                 15000.0
# 1708598                 21000.0
#
#                                    objet_social_parent_lib  \
# 1953767  CULTURE, PRATIQUES D'ACTIVITÉS ARTISTIQUES, PR...
# 227836                                                 NaN
# 286464   CULTURE, PRATIQUES D'ACTIVITÉS ARTISTIQUES, PR...
# 2069618                               ÉDUCATION  FORMATION
# 1708598   SERVICES FAMILIAUX, SERVICES AUX PERSONNES ÂGÉES
#
#                                           objet_social_lib  \
# 1953767  CULTURE, PRATIQUES D'ACTIVITÉS ARTISTIQUES, PR...
# 227836                                                 NaN
# 286464   arts graphiques, bandes dessinées, peinture, s...
# 2069618  organisation de professions enseignantes, amic...
# 1708598  foyers pour personnes âgées, maisons de retrai...
#
#          objet_social_parent_id_2       objet_social_parent_lib_2  \
# 1953767                   11000.0  SPORTS, ACTIVITÉS DE PLEIN AIR
# 227836                        NaN                             NaN
# 286464                        NaN                             NaN
# 2069618                       NaN                             NaN
# 1708598                       NaN                             NaN
#
#                      objet_social_lib_2
# 1953767  SPORTS, ACTIVITÉS DE PLEIN AIR
# 227836                              NaN
# 286464                              NaN
# 2069618                             NaN
# 1708598                             NaN
