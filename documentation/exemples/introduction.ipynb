# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %%
from katalogue.insee.communes import DépôtINSEECommunes

dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC            NCC         NCCENR  \
# 19244     COM  50207  28.0  50  50D  502     0     GOLLEVILLE     Golleville
# 36809     COM  89426  27.0  89  89D  891     0   VAL DE MERCY   Val-de-Mercy
# 26962     COM  64107  75.0  64  64D  641     0     BEHORLEGUY     Béhorléguy
# 25739     COM  62258  32.0  62  62D  621     0      CROISETTE      Croisette
# 26261     COM  62785  32.0  62  62D  621     0  SAVY BERLETTE  Savy-Berlette
#
#              LIBELLE   CAN  COMPARENT
# 19244     Golleville  5004        NaN
# 36809   Val-de-Mercy  8921        NaN
# 26962     Béhorléguy  6412        NaN
# 25739      Croisette  6238        NaN
# 26261  Savy-Berlette  6207        NaN

# %%
from katalogue.datagouv.associations import DépôtDataGouvAssociations

# %%
dépôt = DépôtDataGouvAssociations()
assos = dépôt.associations(sauvegarder_localement=False)
assos.sample(5)
# Out:
#                      id                                              titre  \
# 240862   723P0723010429                     SECOURS ENFANTS DU TIERS MONDE
# 667650   842P0842201292                              CLUB TAURIN ORANGEOIS
# 1700995      W881003523                                ENT'RAID ET PISTONS
# 463930   393S0393001409                            LES AMIS DES DEUX PUITS
# 588151   9R1P9741004590  ASSOCIATION FRATERNITE DES MUSULMANS REUNIONNA...
#
#                                                      objet  objet_social1  \
# 240862   Venir en aide aux enfants victimes d'esclavage...        20020.0
# 667650   FAIRE REVIVRE LES TRADITIONNELLES COURSES LIBR...            0.0
# 1700995  récolter des fonds afin de participer au 4L Tr...        20020.0
# 463930   Organisation d'activites, d'animation au sein ...         7000.0
# 588151   Promouvoir le dialogue islamo-chretien et avec...            0.0
#
#         objet_social2 date_creat adrs_codeinsee adrs_codepostal  \
# ...
