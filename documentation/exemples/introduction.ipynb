# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %%
from katalogue.insee.communes import DépôtINSEECommunes


dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC                       NCC  \
# 12823     COM  32170  76.0  32  32D  323     0                LABARTHETE
# 3193      COM  09236  76.0  09  09D  091     0                   PRAYOLS
# 14324     COM  35316  53.0  35  35D  352     0  SAINT SULPICE DES LANDES
# 1929      COM  05148  93.0  05  05D  052     0     SAINT LAURENT DU CROS
# 36085     COM  88220  44.0  88  88D  882     0              GRIGNONCOURT
#
#                          NCCENR                   LIBELLE   CAN  COMPARENT
# 12823                Labarthète                Labarthète  3201        NaN
# 3193                    Prayols                   Prayols  0912        NaN
# 14324  Saint-Sulpice-des-Landes  Saint-Sulpice-des-Landes  3502        NaN
# 1929      Saint-Laurent-du-Cros     Saint-Laurent-du-Cros  0512        NaN
# 36085              Grignoncourt              Grignoncourt  8804        NaN
