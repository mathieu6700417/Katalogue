# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %% [markdown]
# ## INSEE

# %% [markdown]
# ### Communes

# %%
from katalogue.insee.communes import DépôtINSEECommunes

dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC                 NCC  \
# 19791     COM  51112  44.0  51  51D  513     0             CHAMERY
# 16467     COM  41160  24.0  41  41D  411     0               NEUVY
# 30384     COM  71443  27.0  71  71D  712     0  SAINT LOUP GEANGES
# 20981     COM  53131  52.0  53  53D  533     0             LESBOIS
# 30436     COM  71497  27.0  71  71D  715     0               SANCE
#
#                    NCCENR             LIBELLE   CAN  COMPARENT
# 19791             Chamery             Chamery  5109        NaN
# 16467               Neuvy               Neuvy  4105        NaN
# 30384  Saint-Loup-Géanges  Saint-Loup-Géanges  7116        NaN
# 20981             Lesbois             Lesbois  5307        NaN
# 30436               Sancé               Sancé  7121        NaN

# %% [markdown]
# ## Sirene

# %%
from katalogue.insee.sirene_entreprises import DépôtINSEESireneEntreprises

dépôt = DépôtINSEESireneEntreprises()
dépôt.entreprises(nombre_maximum_entreprises=100)
# Out:
#       siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 0    325175                          O                    NaN
# 1   1807254                          O                    NaN
# 2   5410220                          O                   True
# 3   5410345                          O                   True
# 4   5410394                          O                   True
# ..      ...                        ...                    ...
# 95  5441597                          O                   True
# 96  5441613                          O                   True
# 97  5441621                          O                   True
# 98  5441662                          O                   True
# 99  5450010                          O                   True
#
#    dateCreationUniteLegale  sigleUniteLegale sexeUniteLegale  \
# 0               2000-09-26               NaN               M
# 1               1972-05-01               NaN               M
# ...

# %%
entreprises_de_maraichage = dépôt.entreprises_avec_codes_activite(["01.13Z"], nombre_maximum_entreprises=200)
entreprises_de_maraichage
# Out:
#             siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 21802    24047151                          O                    NaN
# 23174    24082612                          O                    NaN
# 23271    24084824                          O                    NaN
# 23423    25470642                          O                    NaN
# 35023    36813095                          O                    NaN
# ...           ...                        ...                    ...
# 721548  306999368                          O                    NaN
# 721725  307002865                          O                    NaN
# 723006  307027029                          O                    NaN
# 724202  307050112                          O                    NaN
# 724609  307057885                          O                    NaN
#
#        dateCreationUniteLegale sigleUniteLegale sexeUniteLegale  \
# 21802               1998-01-01           COOPAM             NaN
# ...

# %%
coopératives_agricoles = dépôt.entreprises_avec_codes_categorie_juridique([6317], nombre_maximum_entreprises=10)
coopératives_agricoles
# Out:
#             siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 221       5520119                          O                    NaN
# 945       5750500                          O                   True
# 14070    16650913                          O                    NaN
# 21802    24047151                          O                    NaN
# 22302    24060733                          O                    NaN
# 28402    27150184                          O                   True
# 142509   71201594                          O                    NaN
# 146333   72802614                          O                   True
# 172057   99382152                          O                    NaN
# 354116  300016136                          O                   True
#
#        dateCreationUniteLegale sigleUniteLegale sexeUniteLegale  \
# 221                 1955-01-01              NaN             NaN
# 945                        NaN              NaN             NaN
# ...

# %% [markdown]
# ## FAO

# %% [markdown]
# ### Récoltes

# %%
from katalogue.fao.récoltes import DépôtFAORécoltes

dépôt = DépôtFAORécoltes()
récoltes = dépôt.récoltes()

# %% [markdown]
# ### Commerce

# %%
from katalogue.fao.commerce import DépôtFAOCommerce

dépôt = DépôtFAOCommerce()
commerce = dépôt.commerce()

# %%
commerce.sample(3)
# Out:
#           code_pays_déclarant code_pays_déclarant_(m49) pays_déclarants  \
# 11206774                   27                      '100        Bulgarie
# 1850855                    46                      '178           Congo
# 31991047                   11                      '040        Autriche
#
#           code_pays_partenaire code_pays_partenaire_(m49) pays_partenaires  \
# 11206774                    54                       '208         Danemark
# 1850855                     32                       '120         Cameroun
# 31991047                   221                       '512             Oman
#
#           code_produit code_produit_(cpc)  \
# 11206774           252              '2166
# 1850855             20             'F0020
# 31991047          1276             '34120
#
#                                                     produit  code_élément  \
# 11206774                                      Huile de coco          5610
# ...

# %% [markdown]
# ## Data Gouv

# %% [markdown]
# ### Associations

# %%
from katalogue.datagouv.associations import DépôtDataGouvAssociations

# %%
dépôt = DépôtDataGouvAssociations()
assos = dépôt.associations(sauvegarder_localement=True)
# Out:
# Lecture sauvegarde existante  /home/laurent/.katalogue/datagouv/locale_DépôtDataGouvAssociations_associations.pkl

# %%
assos
# Out:
#                      id                                              titre  \
# 0        9G1P9711000010                    ASSOCIATION L'ETOILE BRILLANTE.
# 1        9G1P9711000011  AMICALE RESSERRER LES LIENS D'AMITIE ENTRE SES...
# 2        9G1P9711000012  CLUB LA CONSTITUTION PHYSIQUE DE SES MEMBRES P...
# 3        9G1P9711000013                               CLUB L'INTREPID-CLUB
# 4        9G1P9711000016  AMICALE DES POILUS DE LA GUADELOUPE AIDE AUX O...
# ...                 ...                                                ...
# 3197867      W123005801                          MAM : LE NUAGE DE DOUCEUR
# 3197868      W123005802                                       NOSPORTSCLUB
# 3197869      W123005803                                CLUB AVENTURE CANIN
# 3197870      W123005804                                     FR RALLYE TEAM
# 3197871      W123005805                            MOBILITÉS AVEYRONNAISES
#
# ...

# %% [markdown]
# ## Gutemberg

# %%
from katalogue.gutemberg.livres import DépôtGutembergLivres

dépôt = DépôtGutembergLivres()
catalogue = dépôt.catalogue()
catalogue.sample(3)
# Out:
#        livre_id  type      issued  \
# 992        1011  Text  1997-08-01
# 45958     46032  Text  2014-06-19
# 1561       1583  Text  1998-12-01
#
#                                                title language  \
# 992            La Divina Commedia di Dante: Paradiso       it
# 45958  Vitus Bering: the Discoverer of Bering Strait       en
# 1561                                         Options       en
#
#                                                  authors  \
# 992                           Dante Alighieri, 1265-1321
# 45958  Lauridsen, Peter, 1846-1923; Schwatka, Frederi...
# 1561                                Henry, O., 1862-1910
#
#                                                 subjects locc bookshelves
# 992      Italian poetry -- To 1400; Epic poetry, Italian   PQ   IT Poesia
# 45958  Bering, Vitus Jonassen, 1681-1741; Kamchatskai...    G         NaN
# 1561                    Fiction; Short stories, American   PS         NaN

# %%
texte = dépôt.livre(7470)

# %%
print(texte[3000:5000])
# Out:
# ding
# reigns. Ferdinand and Isabella occasionally set up their pilgrim
# tabernacle on the declivity that overhangs the Manzanares. Charles V.
# found the thin, fine air comforting to his gouty articulations. But
# Philip II. made it his court. It seems hard to conceive how a king who
# had his choice of Lisbon, with its glorious harbor and unequalled
# communications; Seville, with its delicious climate and natural beauty;
# and Salamanca and Toledo, with their wealth of tradition, splendor of
# architecture, and renown of learning, should have chosen this barren
# mountain for his home, and the seat of his empire. But when we know this
# monkish king we wonder no longer. He chose Madrid simply because it was
# cheerless and bare and of ophthalmic ugliness. The royal kill-joy
# delighted in having the dreariest capital on earth. After a while there
# seemed to him too much life and humanity about Madrid, and he built the
# ...
