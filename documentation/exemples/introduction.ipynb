# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %% [markdown]
# ## INSEE

# %% [markdown]
# ### Communes

# %%
from katalogue.insee.communes import DépôtINSEECommunes

dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC                        NCC  \
# 18594     COM  48150  76.0  48  48D  482     0    SAINT FLOUR DE MERCOIRE
# 28185     COM  67063  44.0  67  6AE  675     0                BREITENBACH
# 33553     COM  80124  32.0  80  80D  801     0                BOURSEVILLE
# 12358     COM  31296  76.0  31  31D  312     0  LESTELLE DE SAINT MARTORY
# 29342     COM  69268  84.0  69  69D  691     0                    VOURLES
#
#                           NCCENR                    LIBELLE   CAN  COMPARENT
# 18594    Saint-Flour-de-Mercoire    Saint-Flour-de-Mercoire  4807        NaN
# 28185                Breitenbach                Breitenbach  6711        NaN
# 33553                Bourseville                Bourseville  8016        NaN
# 12358  Lestelle-de-Saint-Martory  Lestelle-de-Saint-Martory  3102        NaN
# 29342                    Vourles                    Vourles  6905        NaN

# %% [markdown]
# ## Sirene

# %%
from katalogue.insee.sirene_entreprises import DépôtINSEESireneEntreprises

dépôt = DépôtINSEESireneEntreprises()
dépôt.entreprises(nombre_maximum_entreprises=100)
# Out:
#       siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 0    325175                          O                    NaN
# 1   1807254                          O                    NaN
# 2   5410220                          O                   True
# 3   5410345                          O                   True
# 4   5410394                          O                   True
# ..      ...                        ...                    ...
# 95  5441597                          O                   True
# 96  5441613                          O                   True
# 97  5441621                          O                   True
# 98  5441662                          O                   True
# 99  5450010                          O                   True
#
#    dateCreationUniteLegale  sigleUniteLegale sexeUniteLegale  \
# 0               2000-09-26               NaN               M
# 1               1972-05-01               NaN               M
# 2               1954-12-25               NaN               M
# 3                      NaN               NaN               M
# 4               1954-12-25               NaN               M
# ..                     ...               ...             ...
# 95                     NaN               NaN               M
# 96                     NaN               NaN               F
# 97                     NaN               NaN               F
# 98                     NaN               NaN               M
# 99                     NaN               NaN             NaN
#
#    prenom1UniteLegale prenom2UniteLegale prenom3UniteLegale  \
# 0             THIERRY                NaN                NaN
# 1      JACQUES-LUCIEN                NaN                NaN
# 2             GEORGES                NaN                NaN
# 3              MICHEL                NaN                NaN
# 4              ROBERT             ALFRED                NaN
# ..                ...                ...                ...
# 95               JEAN                NaN                NaN
# 96                  M                NaN                NaN
# 97          HENRIETTE                EPS              BOREL
# 98               JEAN                NaN                NaN
# 99                NaN                NaN                NaN
#
#     prenom4UniteLegale  ... denominationUsuelle1UniteLegale  \
# 0                  NaN  ...                             NaN
# 1                  NaN  ...                             NaN
# 2                  NaN  ...                             NaN
# 3                  NaN  ...                             NaN
# 4                  NaN  ...                             NaN
# ..                 ...  ...                             ...
# 95                 NaN  ...                             NaN
# 96                 NaN  ...                             NaN
# 97                 NaN  ...                             NaN
# 98                 NaN  ...                             NaN
# 99                 NaN  ...                             NaN
#
#     denominationUsuelle2UniteLegale  denominationUsuelle3UniteLegale  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# ..                              ...                              ...
# 95                              NaN                              NaN
# 96                              NaN                              NaN
# 97                              NaN                              NaN
# 98                              NaN                              NaN
# 99                              NaN                              NaN
#
#    categorieJuridiqueUniteLegale  activitePrincipaleUniteLegale  \
# 0                           1000                         32.12Z
# 1                           1000                         85.59A
# 2                           1000                          22.02
# 3                           1000                          79.06
# 4                           1000                          64.42
# ..                           ...                            ...
# 95                          1000                          64.45
# 96                          1000                          62.44
# 97                          1000                          00.97
# 98                          1000                          62.11
# 99                          5499                          00.97
#
#    nomenclatureActivitePrincipaleUniteLegale  nicSiegeUniteLegale  \
# 0                                    NAFRev2                   65
# 1                                    NAFRev2                   22
# 2                                        NAP                   15
# 3                                        NAP                   10
# 4                                        NAP                   18
# ..                                       ...                  ...
# 95                                       NAP                   19
# 96                                       NAP                   14
# 97                                       NAP                   17
# 98                                       NAP                   11
# 99                                       NAP                   11
#
#    economieSocialeSolidaireUniteLegale  societeMissionUniteLegale  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ..                                 ...                        ...
# 95                                 NaN                        NaN
# 96                                 NaN                        NaN
# 97                                 NaN                        NaN
# 98                                 NaN                        NaN
# 99                                 NaN                        NaN
#
#    caractereEmployeurUniteLegale
# 0                              N
# 1                              N
# 2                              N
# 3                              N
# 4                              N
# ..                           ...
# 95                             N
# 96                             N
# 97                             N
# 98                             N
# 99                             N
#
# [100 rows x 34 columns]

# %%
dépôt.entreprises_avec_codes_activite(["01.11Z", "01.13Z"], nombre_maximum_entreprises=200)
# Out:
#             siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 894       5743182                          O                    NaN
# 1771      5944103                          O                    NaN
# 2377      6044564                          O                    NaN
# 2391      6050116                          O                    NaN
# 3392      6341374                          O                    NaN
# ...           ...                        ...                    ...
# 363442  300206893                          O                    NaN
# 363481  300207628                          O                    NaN
# 363689  300211620                          O                    NaN
# 363723  300212339                          O                    NaN
# 364163  300221082                          O                    NaN
#
#        dateCreationUniteLegale sigleUniteLegale sexeUniteLegale  \
# 894                 1957-01-01              NaN               M
# 1771                1959-01-01              NaN               F
# 2377                1960-01-01              NaN               M
# 2391                1960-01-01              NaN             NaN
# 3392                1963-01-01              NaN               M
# ...                        ...              ...             ...
# 363442              1900-01-01              NaN               M
# 363481              1974-01-01              NaN               M
# 363689              1974-01-01              NaN               F
# 363723              1974-01-01              NaN               M
# 364163              1900-01-01              NaN             NaN
#
#        prenom1UniteLegale prenom2UniteLegale prenom3UniteLegale  \
# 894                LUCIEN                NaN                NaN
# 1771             GERMAINE                NaN                NaN
# 2377            CHRISTIAN                NaN                NaN
# 2391                  NaN                NaN                NaN
# 3392              FERNAND                NaN                NaN
# ...                   ...                ...                ...
# 363442               JEAN             PIERRE                NaN
# 363481             CLAUDE             MARCEL               JEAN
# 363689            LILIANE          GHYSLAINE                NaN
# 363723              SERGE                NaN                NaN
# 364163                NaN                NaN                NaN
#
#        prenom4UniteLegale  ... denominationUsuelle1UniteLegale  \
# 894                   NaN  ...                             NaN
# 1771                  NaN  ...                             NaN
# 2377                  NaN  ...                             NaN
# 2391                  NaN  ...                             NaN
# 3392                  NaN  ...                             NaN
# ...                   ...  ...                             ...
# 363442                NaN  ...                             NaN
# 363481                NaN  ...                             NaN
# 363689                NaN  ...                             NaN
# 363723                NaN  ...                             NaN
# 364163                NaN  ...                             NaN
#
#        denominationUsuelle2UniteLegale denominationUsuelle3UniteLegale  \
# 894                                NaN                             NaN
# 1771                               NaN                             NaN
# 2377                               NaN                             NaN
# 2391                               NaN                             NaN
# 3392                               NaN                             NaN
# ...                                ...                             ...
# 363442                             NaN                             NaN
# 363481                             NaN                             NaN
# 363689                             NaN                             NaN
# 363723                             NaN                             NaN
# 364163                             NaN                             NaN
#
#        categorieJuridiqueUniteLegale  activitePrincipaleUniteLegale  \
# 894                             1000                         01.11Z
# 1771                            1000                         01.11Z
# 2377                            1000                         01.11Z
# 2391                            5599                         01.11Z
# 3392                            1000                         01.11Z
# ...                              ...                            ...
# 363442                          1000                         01.11Z
# 363481                          1000                         01.11Z
# 363689                          1000                         01.11Z
# 363723                          1000                         01.11Z
# 364163                          6533                         01.11Z
#
#        nomenclatureActivitePrincipaleUniteLegale  nicSiegeUniteLegale  \
# 894                                      NAFRev2                   23
# 1771                                     NAFRev2                   26
# 2377                                     NAFRev2                   34
# 2391                                     NAFRev2                   18
# 3392                                     NAFRev2                   20
# ...                                          ...                  ...
# 363442                                   NAFRev2                   12
# 363481                                   NAFRev2                   29
# 363689                                   NAFRev2                   38
# 363723                                   NAFRev2                   42
# 364163                                   NAFRev2                   13
#
#        economieSocialeSolidaireUniteLegale  societeMissionUniteLegale  \
# 894                                    NaN                        NaN
# 1771                                   NaN                        NaN
# 2377                                   NaN                        NaN
# 2391                                   NaN                        NaN
# 3392                                   NaN                        NaN
# ...                                    ...                        ...
# 363442                                 NaN                        NaN
# 363481                                 NaN                        NaN
# 363689                                 NaN                        NaN
# 363723                                 NaN                        NaN
# 364163                                 NaN                        NaN
#
#        caractereEmployeurUniteLegale
# 894                                N
# 1771                               N
# 2377                               N
# 2391                               N
# 3392                               N
# ...                              ...
# 363442                             N
# 363481                             N
# 363689                             N
# 363723                             O
# 364163                             N
#
# [200 rows x 34 columns]

# %%
coopératives_agricoles = dépôt.entreprises_avec_codes_categorie_juridique([6317], nombre_maximum_entreprises=10)
coopératives_agricoles
# Out:
#             siren statutDiffusionUniteLegale unitePurgeeUniteLegale  \
# 221       5520119                          O                    NaN
# 945       5750500                          O                   True
# 14070    16650913                          O                    NaN
# 21802    24047151                          O                    NaN
# 22302    24060733                          O                    NaN
# 28402    27150184                          O                   True
# 142509   71201594                          O                    NaN
# 146333   72802614                          O                   True
# 172057   99382152                          O                    NaN
# 354116  300016136                          O                   True
#
#        dateCreationUniteLegale sigleUniteLegale sexeUniteLegale  \
# 221                 1955-01-01              NaN             NaN
# 945                        NaN              NaN             NaN
# 14070               1900-01-01              NaN             NaN
# 21802               1998-01-01           COOPAM             NaN
# 22302               1999-11-28              NaN             NaN
# 28402                      NaN              NaN             NaN
# 142509              1900-01-01              NaN             NaN
# 146333                     NaN              NaN             NaN
# 172057              1997-04-16              NaN             NaN
# 354116                     NaN              NaN             NaN
#
#        prenom1UniteLegale prenom2UniteLegale prenom3UniteLegale  \
# 221                   NaN                NaN                NaN
# 945                   NaN                NaN                NaN
# 14070                 NaN                NaN                NaN
# 21802                 NaN                NaN                NaN
# 22302                 NaN                NaN                NaN
# 28402                 NaN                NaN                NaN
# 142509                NaN                NaN                NaN
# 146333                NaN                NaN                NaN
# 172057                NaN                NaN                NaN
# 354116                NaN                NaN                NaN
#
#        prenom4UniteLegale  ... denominationUsuelle1UniteLegale  \
# 221                   NaN  ...                  L'ABBEVILLOISE
# 945                   NaN  ...                             NaN
# 14070                 NaN  ...                             NaN
# 21802                 NaN  ...                             NaN
# 22302                 NaN  ...                             NaN
# 28402                 NaN  ...                             NaN
# 142509                NaN  ...                             NaN
# 146333                NaN  ...                             NaN
# 172057                NaN  ...                             NaN
# 354116                NaN  ...                             NaN
#
#        denominationUsuelle2UniteLegale denominationUsuelle3UniteLegale  \
# 221                                NaN                             NaN
# 945                                NaN                             NaN
# 14070                              NaN                             NaN
# 21802                              NaN                             NaN
# 22302                              NaN                             NaN
# 28402                              NaN                             NaN
# 142509                             NaN                             NaN
# 146333                             NaN                             NaN
# 172057                             NaN                             NaN
# 354116                             NaN                             NaN
#
#        categorieJuridiqueUniteLegale  activitePrincipaleUniteLegale  \
# 221                             6317                          51.2A
# 945                             6317                          62.12
# 14070                           6317                          51.2A
# 21802                           6317                         01.13Z
# 22302                           6317                         43.99C
# 28402                           6317                          57.04
# 142509                          6317                         46.31Z
# 146333                          6317                          59.04
# 172057                          6317                         23.32Z
# 354116                          6317                          36.10
#
#        nomenclatureActivitePrincipaleUniteLegale  nicSiegeUniteLegale  \
# 221                                      NAF1993                   24
# 945                                          NAP                   18
# 14070                                    NAF1993                   11
# 21802                                    NAFRev2                   14
# 22302                                    NAFRev2                   11
# 28402                                        NAP                   29
# 142509                                   NAFRev2                   42
# 146333                                       NAP                   15
# 172057                                   NAFRev2                   17
# 354116                                       NAP                   16
#
#        economieSocialeSolidaireUniteLegale  societeMissionUniteLegale  \
# 221                                    NaN                        NaN
# 945                                    NaN                        NaN
# 14070                                  NaN                        NaN
# 21802                                    O                        NaN
# 22302                                    O                        NaN
# 28402                                  NaN                        NaN
# 142509                                   O                        NaN
# 146333                                 NaN                        NaN
# 172057                                   O                        NaN
# 354116                                 NaN                        NaN
#
#        caractereEmployeurUniteLegale
# 221                                N
# 945                                N
# 14070                              N
# 21802                              O
# 22302                              O
# 28402                              N
# 142509                             O
# 146333                             N
# 172057                             O
# 354116                             N
#
# [10 rows x 34 columns]

# %% [markdown]
# ## FAO

# %% [markdown]
# ### Récoltes

# %%
from katalogue.fao.récoltes import DépôtFAORécoltes

dépôt = DépôtFAORécoltes()
récoltes = dépôt.récoltes()

# %% [markdown]
# ### Commerce

# %%
from katalogue.fao.commerce import DépôtFAOCommerce

dépôt = DépôtFAOCommerce()
commerce = dépôt.commerce()

# %%
commerce.sample(3)
# Out:
#           code_pays_déclarant code_pays_déclarant_(m49) pays_déclarants  \
# 11206774                   27                      '100        Bulgarie
# 1850855                    46                      '178           Congo
# 31991047                   11                      '040        Autriche
#
#           code_pays_partenaire code_pays_partenaire_(m49) pays_partenaires  \
# 11206774                    54                       '208         Danemark
# 1850855                     32                       '120         Cameroun
# 31991047                   221                       '512             Oman
#
#           code_produit code_produit_(cpc)  \
# 11206774           252              '2166
# 1850855             20             'F0020
# 31991047          1276             '34120
#
#                                                     produit  code_élément  \
# 11206774                                      Huile de coco          5610
# 1850855                                                Pain          5610
# 31991047  Acides gras monocarboxyliques industriels; hui...          5910
#
#                           élément  code_année  année   unité  valeur symbole
# 11206774  Importations - Quantité        2014   2014  tonnes     1.0       A
# 1850855   Importations - Quantité        2013   2013  tonnes     1.0       A
# 31991047  Exportations - Quantité        2004   2004  tonnes     1.0       A

# %% [markdown]
# ## Data Gouv

# %% [markdown]
# ### Associations

# %%
from katalogue.datagouv.associations import DépôtDataGouvAssociations

# %%
dépôt = DépôtDataGouvAssociations()
assos = dépôt.associations(sauvegarder_localement=False)

# %%
assos
# Out:
#                      id                                              titre  \
# 0        711S0711000019                                 LA GAULE AUTUNOISE
# 1        711S0711000036                           LA LIBRE PENSEE D'EPINAC
# 2        711S0711000041                              LE SOUCI DU LENDEMAIN
# 3        711S0711000074                    SYNDICAT DE CHASSEURS DE DEZIZE
# 4        711S0711000080  ASS. DES CHEFS DE FAMILLES CATHOLIQUES DU CANT...
# ...                 ...                                                ...
# 3197867      W613005263                                      BLEU EPHEMERE
# 3197868      W613005264                        ÉDITIONS LES MONDES MUTANTS
# 3197869      W613005265                                   BALL TRAP PERCHE
# 3197870      W613005266                               LA RECYCL' DE LONGNY
# 3197871      W613005267                                    LES COUR'JOUONS
#
#                                                      objet  objet_social1  \
# 0        OBTENIR L'AFFERMAGE DE LOTS DE PECHE SUR LE TE...        13010.0
# 1        FOURNIT AUX SOCIETAIRES DES TEMOINS AUX MAIRIE...        19000.0
# 2        PARER AUX PREMIERS BESOINS OCCASIONNES PAR LE ...        19000.0
# 3        REPRESSION DU BRACONNAGE ET VEILLER Â LA PREPA...        13005.0
# 4        ASSURER LA NEUTRALITE A L'ECOLE, LA PROTECTION...        15005.0
# ...                                                    ...            ...
# 3197867  Promouvoir et développer les activités artisti...         6020.0
# 3197868  Créer, éditer et diffuser des romans, des recu...         7000.0
# 3197869  Cette association a un but sportif et non lucr...        11000.0
# 3197870  actions environnementales : donner une seconde...        24005.0
# 3197871  cette association a pour objet la gestion admi...        14030.0
#
#         objet_social2 date_creat adrs_codeinsee adrs_codepostal  \
# 0                 0.0        NaT          71014           71400
# 1                 0.0        NaT          71190           71360
# 2                 0.0        NaT          71014           71400
# 3                 0.0        NaT          71174           71150
# 4                 0.0        NaT          71239           71760
# ...               ...        ...            ...             ...
# 3197867             0 2022-10-10          61097         61400.0
# 3197868             0 2022-10-12          61038         61130.0
# 3197869         10000 2022-10-20          61394         61130.0
# 3197870         20000 2022-10-20          61230         61290.0
# 3197871         10000 2022-10-26          61029         61560.0
#
#                          titre_court date_disso  objet_social_parent_id  \
# 0                                NaN        NaT                 13000.0
# 1                                NaN        NaT                 19000.0
# 2                                NaN        NaT                 19000.0
# 3                                NaN        NaT                 13000.0
# 4                                NaN        NaT                 15000.0
# ...                              ...        ...                     ...
# 3197867                BLEU EPHEMERE        NaT                  6000.0
# 3197868  EDITIONS LES MONDES MUTANTS        NaT                  7000.0
# 3197869                    BT PERCHE        NaT                 11000.0
# 3197870                   LA RECYCL'        NaT                 24000.0
# 3197871              LES COUR'JOUONS        NaT                 14000.0
#
#                                    objet_social_parent_lib  \
# 0                                             CHASSE PÊCHE
# 1                                   INTERVENTIONS SOCIALES
# 2                                   INTERVENTIONS SOCIALES
# 3                                             CHASSE PÊCHE
# 4                                     ÉDUCATION  FORMATION
# ...                                                    ...
# 3197867  CULTURE, PRATIQUES D'ACTIVITÉS ARTISTIQUES, PR...
# 3197868                        CLUBS DE LOISIRS, RELATIONS
# 3197869                     SPORTS, ACTIVITÉS DE PLEIN AIR
# 3197870                       ENVIRONNEMENT,  CADRE DE VIE
# 3197871  AMICALES, GROUPEMENTS AFFINITAIRES, GROUPEMENT...
#
#                                           objet_social_lib  \
# 0                                                    pêche
# 1                                   INTERVENTIONS SOCIALES
# 2                                   INTERVENTIONS SOCIALES
# 3                                                   chasse
# 4                                         parents d'élèves
# ...                                                    ...
# 3197867  arts graphiques, bandes dessinées, peinture, s...
# 3197868                        CLUBS DE LOISIRS, RELATIONS
# 3197869                     SPORTS, ACTIVITÉS DE PLEIN AIR
# 3197870                         pollutions, assainissement
# 3197871  association du personnel d'une entreprise (hor...
#
#          objet_social_parent_id_2  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3197867                       NaN
# 3197868                       NaN
# 3197869                   10000.0
# 3197870                   20000.0
# 3197871                   10000.0
#
#                                  objet_social_parent_lib_2  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3197867                                                NaN
# 3197868                                                NaN
# 3197869                         PRÉSERVATION DU PATRIMOINE
# 3197870  ASSOCIATIONS CARITATIVES, HUMANITAIRES, AIDE A...
# 3197871                         PRÉSERVATION DU PATRIMOINE
#
#                                         objet_social_lib_2
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3197867                                                NaN
# 3197868                                                NaN
# 3197869                         PRÉSERVATION DU PATRIMOINE
# 3197870  ASSOCIATIONS CARITATIVES, HUMANITAIRES, AIDE A...
# 3197871                         PRÉSERVATION DU PATRIMOINE
#
# [3197872 rows x 16 columns]
