# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("/".join(os.getcwd().split("/")[:-2]) + "/")

# %%
from katalogue.insee.communes import DépôtINSEECommunes


dépôt = DépôtINSEECommunes()
communes = dépôt.communes()
communes.sample(5)
# Out:
#       TYPECOM    COM   REG DEP CTCD  ARR  TNCC                  NCC  \
# 34445     COM  81207  76.0  81  81D  812     0            PEYREGOUX
# 6496      COM  17477  75.0  17  17D  175     0     VILLIERS COUTURE
# 11296     COM  29243  53.0  29  29D  292     0        SAINT COULITZ
# 938       COM  02512  32.0  02  02D  021     0    MONTIGNY L ALLIER
# 23546     COM  58251  27.0  58  58D  584     0  SAINT LOUP DES BOIS
#
#                     NCCENR              LIBELLE   CAN  COMPARENT
# 34445            Peyregoux            Peyregoux  8120        NaN
# 6496      Villiers-Couture     Villiers-Couture  1711        NaN
# 11296        Saint-Coulitz        Saint-Coulitz  2909        NaN
# 938      Montigny-l'Allier    Montigny-l'Allier  0221        NaN
# 23546  Saint-Loup-des-Bois  Saint-Loup-des-Bois  5805        NaN

# %%
from katalogue.fao.récoltes import DépôtFAORécoltes

dépôt = DépôtFAORécoltes()
récoltes = dépôt.récoltes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 4
#       1 from katalogue.fao.récoltes import DépôtFAORécoltes
#       3 dépôt = DépôtFAORécoltes()
# ----> 4 récoltes = dépôt.récoltes()
#
# File ~/Documents/Code/Python/katalogue/katalogue/fao/récoltes.py:16, in DépôtFAORécoltes.récoltes(self)
#      14 self.télécharger("t_z")
#      15 self.décompresser("t_z")
# ---> 16 self.décompresser("t_z.commerce")
#      18 df = pd.read_csv(self.chemin_fichier("t_z.commerce.data"), encoding="latin-1")
#      19 df.columns = list(map(lambda c: c.lower().replace(" ", "_"), df.columns))
#
# File ~/Documents/Code/Python/katalogue/katalogue/dépot.py:37, in Dépot.décompresser(self, nom_source)
#      36 def décompresser(self, nom_source):
# ---> 37     chemin_fichier = self.chemin_fichier(nom_source)
#      38     with zipfile.ZipFile(chemin_fichier, 'r') as zip_ref:
#      39         zip_ref.extractall(self.dossier)
#
# File ~/Documents/Code/Python/katalogue/katalogue/dépot.py:43, in Dépot.chemin_fichier(self, nom_source)
#      42 def chemin_fichier(self, nom_source):
# ---> 43     return os.path.join(self.dossier, self.config.get(nom_source).get('fichier'))
#
# AttributeError: 'NoneType' object has no attribute 'get'
